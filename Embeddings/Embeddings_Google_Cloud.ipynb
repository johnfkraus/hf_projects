# %% [markdown]
# https://medium.com/@pradeepgoel/demystifying-embeddings-b680e095b145#id_token=eyJhbGciOiJSUzI1NiIsImtpZCI6Ijk4ZGM1NWM4YjIwOTM2M2EyNDUxNzc0YmNlNWM0MjcxOGQxM2NiN2QiLCJ0eXAiOiJKV1QifQ.....fZlcsaQVO1nf-whCq8ef0RaxTFwdZiKqBztRWG2BID1tadQTU-odaQX0GTsueoKO0OjmPj9MAYAd3DdEyvnAS10tellxPoIBSIQ-npQKYvo1kOZpedGNGQxtrfSndz0iOxq7SwbaOY7CigZtqxQ06dcre8nBS5oIJeuLpy-yIn8i8T65R9FxQPD8CvLQiLHpk1ZpJI9vhcSuw5Xhco3qfVJriyby6PB3ZmRbAffHDdcMrnYAgk888a9Qj4unzDeUbQuXw8IwBaC5Poh4dqly8RLmipwwzlWH-cykDYhxVL1-mvlq3eVjC7SgZ_YMGqmSQcyyVP_N2_cjfF1xJW57nQ

# %%
# pip install vertexai

# %%
# !source ~/.zshrc

# %%
# !which gcloud
# Out:
# /Users/blauerbock/google-cloud-sdk/bin/gcloud

# %%
# !gcloud auth login
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=ua6dTLgd5t9LcOBVvvcbqO1jDGDcKF&access_type=offline&code_challenge=CoH3XkCM8PPgTi0Y9XVMoRH_gTdZe6sdWEN-Ccfkm1I&code_challenge_method=S256
#
#
# You are now logged in as [johnkraus3@gmail.com].
# Your current project is [embeddings-22101].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID

# %%
# !gcloud config set project 'embeddings-22101'
# Out:
# Updated property [core/project].

# %%
# Settign up an embedding model

from vertexai.language_models import TextEmbeddingModel

embedding_model = TextEmbeddingModel.from_pretrained(
    "textembedding-gecko@001")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File /opt/anaconda3/envs/py313/lib/python3.13/site-packages/google/cloud/aiplatform/initializer.py:356, in _Config.project(self)
#     355 try:
# --> 356     self._set_project_as_env_var_or_google_auth_default()
#     357     project_id = self._project
#
# File /opt/anaconda3/envs/py313/lib/python3.13/site-packages/google/cloud/aiplatform/initializer.py:112, in _Config._set_project_as_env_var_or_google_auth_default(self)
#     111 else:
# --> 112     credentials, project = google.auth.default()
#     113     self._credentials = self._credentials or credentials
#
# File /opt/anaconda3/envs/py313/lib/python3.13/site-packages/google/auth/_default.py:685, in default(scopes, request, quota_project_id, default_scopes)
#     683         return credentials, effective_project_id
# ...
